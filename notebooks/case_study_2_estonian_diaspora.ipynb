# %%
# Import the libraries
import pandas as pd
import numpy as np

# %%
# Read in file, which contains information of all books in the ENB
df_books = pd.read_parquet('enb_books.parquet', engine='pyarrow')

# %%
# Control if the file was read in correctly
df_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311950 entries, 0 to 311949
# Data columns (total 55 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   id                               311950 non-null  string
#  1   date_entered                     311402 non-null  datetime64[ns]
#  2   isbn                             176505 non-null  string
#  3   creator                          190290 non-null  string
#  4   contributor                      189373 non-null  string
#  5   publisher                        300498 non-null  string
#  6   title                            311950 non-null  string
#  7   title_remainder                  167068 non-null  string
#  8   title_part_nr                    24584 non-null   string
#  9   title_part_nr_cleaned            24524 non-null   string
#  10  title_varform                    99930 non-null   string
#  11  title_original                   53901 non-null   string
#  12  title_freeform                   23903 non-null   string
#  13  publication_date_control         311946 non-null  string
#  14  publication_date                 311940 non-null  string
#  15  publication_date_cleaned         310037 non-null  Int64
#  16  publication_decade               311448 non-null  Int64
#  17  publication_place_control        311946 non-null  string
#  18  publication_place                311935 non-null  string
#  19  publication_place_harmonized     311935 non-null  string
#  20  publication_place_latitude       310216 non-null  Float64
#  21  publication_place_longitude      310216 non-null  Float64
#  22  manufacturing_place              203791 non-null  string
#  23  manufacturer                     193118 non-null  string
#  24  corporate_unit                   109787 non-null  string
#  25  series_statement                 63859 non-null   string
#  26  edition_statement                21983 non-null   string
#  27  edition_n                        21983 non-null   string
#  28  original_distribution_year       16030 non-null   Int64
#  29  original_distribution_place      11872 non-null   string
#  30  original_distribution_publisher  10150 non-null   string
#  31  language                         311946 non-null  string
#  32  language_additional              110739 non-null  string
#  33  language_original                76119 non-null   string
#  34  language_note                    35949 non-null   string
#  35  is_fiction                       310145 non-null  boolean
#  36  is_posthumous                    189519 non-null  boolean
#  37  udc                              274860 non-null  string
#  38  topic_keyword                    290265 non-null  string
#  39  genre_keyword                    256740 non-null  string
#  40  geographic_keyword               101342 non-null  string
#  41  chronological_keyword            17683 non-null   string
#  42  corporate_keyword                38667 non-null   string
#  43  person_keyword                   27280 non-null   string
#  44  page_count                       282174 non-null  Int64
#  45  is_illustrated                   311950 non-null  boolean
#  46  physical_size                    262963 non-null  Int64
#  47  print_run                        14862 non-null   Int64
#  48  price                            5261 non-null    string
#  49  typeface                         22293 non-null   string
#  50  has_bibliography_register        81438 non-null   string
#  51  copyright_status                 54770 non-null   string
#  52  is_digitized                     311950 non-null  boolean
#  53  digitized_year                   62592 non-null   string
#  54  access_uri                       115180 non-null  string
# dtypes: Float64(2), Int64(6), boolean(4), datetime64[ns](1), string(42)
# memory usage: 126.1 MB

# %%
# Define time periods
books_18_39 = df_books[(df_books['publication_date_cleaned'] >= 1918) & (df_books['publication_date_cleaned'] <= 1939)].copy()
books_40_91 = df_books[(df_books['publication_date_cleaned'] >= 1940) & (df_books['publication_date_cleaned'] <= 1991)].copy()

# Count occurrences of harmonised place names
books_18_39_counts = books_18_39.groupby(['publication_place_harmonized', 'publication_place_latitude', 'publication_place_longitude']).size().reset_index(name='book_count')
books_40_91_counts = books_40_91.groupby(['publication_place_harmonized', 'publication_place_latitude', 'publication_place_longitude']).size().reset_index(name='book_count')

# Calculate the total number of books across both periods
total_counts = pd.concat([books_18_39_counts.assign(period='1918-1939'), books_40_91_counts.assign(period='1940-1991')])
total_counts_by_location = total_counts.groupby(['publication_place_latitude', 'publication_place_longitude']).agg(
    total_book_count=('book_count', 'sum')
).reset_index()

# Calculate log counts for normalisation
total_counts_by_location['log_book_count'] = np.log1p(total_counts_by_location['total_book_count'])  # log1p handles log(0) case

# Determine the maximum total book count for normalisation
max_total_count = total_counts_by_location['log_book_count'].max()

# Normalise the book counts in each dataset based on the overall maximum
books_18_39_counts['log_book_count'] = np.log1p(books_18_39_counts['book_count'])
books_18_39_counts['normalized_book_count'] = books_18_39_counts['log_book_count'] / max_total_count

books_40_91_counts['log_book_count'] = np.log1p(books_40_91_counts['book_count'])
books_40_91_counts['normalized_book_count'] = books_40_91_counts['log_book_count'] / max_total_count

# Save the dataframes as CSV files, which would be further visualised with QGIS
books_18_39_counts.to_csv('books_18_39_counts.csv', index=False)
books_40_91_counts.to_csv('books_40_91_counts.csv', index=False)

# %%
# Focusing on how many books were published in Stockholm, where most Estonian diaspora literature was published during the Cold War
publication_place_stockholm = books_40_91[books_40_91['publication_place_harmonized'] == 'Stockholm']
publication_place_stockholm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1340 entries, 209 to 311925
# Data columns (total 55 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               1340 non-null   string
#  1   date_entered                     1339 non-null   datetime64[ns]
#  2   isbn                             342 non-null    string
#  3   creator                          895 non-null    string
#  4   contributor                      642 non-null    string
#  5   publisher                        1311 non-null   string
#  6   title                            1340 non-null   string
#  7   title_remainder                  795 non-null    string
#  8   title_part_nr                    151 non-null    string
#  9   title_part_nr_cleaned            150 non-null    string
#  10  title_varform                    222 non-null    string
#  11  title_original                   42 non-null     string
#  12  title_freeform                   54 non-null     string
#  13  publication_date_control         1340 non-null   string
#  14  publication_date                 1340 non-null   string
#  15  publication_date_cleaned         1340 non-null   Int64
#  16  publication_decade               1340 non-null   Int64
#  17  publication_place_control        1340 non-null   string
#  18  publication_place                1340 non-null   string
#  19  publication_place_harmonized     1340 non-null   string
#  20  publication_place_latitude       1340 non-null   Float64
#  21  publication_place_longitude      1340 non-null   Float64
#  22  manufacturing_place              728 non-null    string
#  23  manufacturer                     713 non-null    string
#  24  corporate_unit                   288 non-null    string
#  25  series_statement                 278 non-null    string
#  26  edition_statement                111 non-null    string
#  27  edition_n                        111 non-null    string
#  28  original_distribution_year       64 non-null     Int64
#  29  original_distribution_place      62 non-null     string
#  30  original_distribution_publisher  36 non-null     string
#  31  language                         1340 non-null   string
#  32  language_additional              249 non-null    string
#  33  language_original                67 non-null     string
#  34  language_note                    164 non-null    string
#  35  is_fiction                       1315 non-null   boolean
#  36  is_posthumous                    895 non-null    boolean
#  37  udc                              1330 non-null   string
#  38  topic_keyword                    1288 non-null   string
#  39  genre_keyword                    926 non-null    string
#  40  geographic_keyword               671 non-null    string
#  41  chronological_keyword            181 non-null    string
#  42  corporate_keyword                157 non-null    string
#  43  person_keyword                   171 non-null    string
#  44  page_count                       1275 non-null   Int64
#  45  is_illustrated                   1340 non-null   boolean
#  46  physical_size                    1122 non-null   Int64
#  47  print_run                        7 non-null      Int64
#  48  price                            0 non-null      string
#  49  typeface                         0 non-null      string
#  50  has_bibliography_register        391 non-null    string
#  51  copyright_status                 29 non-null     string
#  52  is_digitized                     1340 non-null   boolean
#  53  digitized_year                   199 non-null    string
#  54  access_uri                       239 non-null    string
# dtypes: Float64(2), Int64(6), boolean(4), datetime64[ns](1), string(42)
# memory usage: 565.3 KB

# %%
# Investigating in which languages the books were written
publication_place_stockholm['language'].value_counts()
# Out:
# est    776
# swe    325
# eng    162
# ger     62
# fre      7
# fin      5
# spa      1
# cze      1
# rus      1
# Name: language, dtype: Int64

# %%
# Investigating certain topic keywords, such as "eesti" ("Estonia") and "väliseesti" ("exile Estonia")
value1 = "eesti [EMS174969]"
value2 = "väliseesti [EMS021662]"
topic_keyword_stockholm = publication_place_stockholm[
    publication_place_stockholm['topic_keyword'].fillna('').apply(
        lambda x: (
            value1 == x or value2 == x or
            value1 in [part.strip() for part in x.split(';')] or value2 in [part.strip() for part in x.split(';')]
        )
    )
]

# %%
# Studying how many books were published, which had these topics as the content
topic_keyword_stockholm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 520 entries, 1676 to 311925
# Data columns (total 55 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               520 non-null    string
#  1   date_entered                     520 non-null    datetime64[ns]
#  2   isbn                             129 non-null    string
#  3   creator                          298 non-null    string
#  4   contributor                      320 non-null    string
#  5   publisher                        515 non-null    string
#  6   title                            520 non-null    string
#  7   title_remainder                  366 non-null    string
#  8   title_part_nr                    48 non-null     string
#  9   title_part_nr_cleaned            47 non-null     string
#  10  title_varform                    84 non-null     string
#  11  title_original                   14 non-null     string
#  12  title_freeform                   14 non-null     string
#  13  publication_date_control         520 non-null    string
#  14  publication_date                 520 non-null    string
#  15  publication_date_cleaned         520 non-null    Int64
#  16  publication_decade               520 non-null    Int64
#  17  publication_place_control        520 non-null    string
#  18  publication_place                520 non-null    string
#  19  publication_place_harmonized     520 non-null    string
#  20  publication_place_latitude       520 non-null    Float64
#  21  publication_place_longitude      520 non-null    Float64
#  22  manufacturing_place              314 non-null    string
#  23  manufacturer                     309 non-null    string
#  24  corporate_unit                   110 non-null    string
#  25  series_statement                 59 non-null     string
#  26  edition_statement                35 non-null     string
#  27  edition_n                        35 non-null     string
#  28  original_distribution_year       24 non-null     Int64
#  29  original_distribution_place      23 non-null     string
#  30  original_distribution_publisher  17 non-null     string
#  31  language                         520 non-null    string
#  32  language_additional              87 non-null     string
#  33  language_original                25 non-null     string
#  34  language_note                    61 non-null     string
#  35  is_fiction                       504 non-null    boolean
#  36  is_posthumous                    298 non-null    boolean
#  37  udc                              519 non-null    string
#  38  topic_keyword                    520 non-null    string
#  39  genre_keyword                    436 non-null    string
#  40  geographic_keyword               147 non-null    string
#  41  chronological_keyword            42 non-null     string
#  42  corporate_keyword                90 non-null     string
#  43  person_keyword                   76 non-null     string
#  44  page_count                       504 non-null    Int64
#  45  is_illustrated                   520 non-null    boolean
#  46  physical_size                    426 non-null    Int64
#  47  print_run                        6 non-null      Int64
#  48  price                            0 non-null      string
#  49  typeface                         0 non-null      string
#  50  has_bibliography_register        79 non-null     string
#  51  copyright_status                 7 non-null      string
#  52  is_digitized                     520 non-null    boolean
#  53  digitized_year                   74 non-null     string
#  54  access_uri                       90 non-null     string
# dtypes: Float64(2), Int64(6), boolean(4), datetime64[ns](1), string(42)
# memory usage: 219.4 KB
